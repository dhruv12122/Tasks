# %%
# Q1 Two sum
def twoSum(self, nums, target):
    seen = {}
    for i, num in enumerate(nums):
        compliment = target - num

        if compiment in seen:
            return [seen[compliment], i]

# %%
# Q3 Longest Substring Without Repeating Characters - 25 mins 
def lengthOfLongestSubstring(self, s):
    seen = set()
    left = 0
    max_length = 0

    for right in range(len(s)):
        if right in seen:
            seen.remove(s[left])
            left += 1

        seen.add(s[right])
        max_length = max(max_length, right - left + 1)

    return max_length

# %%
# Q4 Palindrome Number - 10 mins
def isPalindrome(self, x):
    if x < 0:
        return False

    original = x
    reverse = 0

    while x > 0:
        digit = x % 10
        reverse = reverse * 10 + digit 
        x //= 10

    return original == reverse

# %%
# Q5 Container with most height - 30 mins
def maxArea(self, height):
    left = 0
    right = len(height) - 1
    max_area = 0

    while left < right:
        width = right - left
        current_area = min(height[left], height[right]) * width
        max_area = max(max_area, current_area)

        if height[left] < height[right]:
            left += 1
        else:
            right -= 1

    return max_area

# %%
# Q6 Roman To Integer - 10 mins
def romanToInt(self, s):
    values = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
    total = 0 

    for i in range(len(s)):
        if i + 1 < len(s) and values[s[i]] < values[s[i + 1]]:
            total -= values[s[i]]
        else:
            total += values[s[i]]

    return total

# %%
# Q7 Longest Commom Prefix - 20 mins 
def longestCommonPrefix(self, strs):
    prefix = ""
    
    for i in range(len(strs[0])):
        char = strs[0][i]

        for word in strs:
            if i >= len(word) or word[i] != char:
                return prefix

        prefix += char

    return prefix

# %%
#Q9 Valid Parantheses
def isValid(self, s):
    stack = []
        pairs = {
            ")": "(",
            "]": "[",
            "}": "{"
        }

        for char in s:
            if char in "([{":
                stack.append(char)
            elif char in ")]}":
                if not stack:
                    return False
                top = stack.pop[char]
                if top != pairs[char]:
                    return False

        return len(stack) == 0

# %%
# Q10 Merge 2 Sorted Lists
def mergeTwoLists(self, list1, list2):
    dummy = ListNode(0)
    current = dummy

    while list1 and list2:
        if list1.val < list2.val:
            current.next = list1
            list1 = list1.next
        else:
            current.next = list2
            list2 = list2.next

        current = current.next

    if list1:
        current.next = list1
    else:
        current.next = list2

    return dummy.next

# %%
#Q11 Merge 2 Sorted Lists - 12 mins 
def mergeTwoLists(self, list1, list2):
        dummy = ListNode(0)
        current = dummy

        while list1 and list2:
            if list1.val < list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next

            current = current.next

        if list1:
            current.next = list1
        else:
            current.next = list2

        return dummy.next

# %%
# Q12 Remove Duplicates from sorted array - 8 mins
def removeDuplicates(self, nums):
    if not nums:
        return 0
    
    write = 1
    
    for read in range(1, len(nums)):
        if nums[read] != nums[write - 1]:
        nums[write] = nums[read]
        write += 1

    return write

# %%
# Q13 Search in rotated sorted array
def search(self, nums, target):
    left = 0
    right = len(nums) - 1

    while left <= right:
        mid = (left + right) // 2

        if nums[mid] == target:
            return mid
        elif nums[left] < nums[mid]:
            if nums[left] <= target < nums[mid]:
                right = mid - 1
            else:
                left += 1
        else:
            if nums[mid] < target <= nums[right]:
                left = mid + 1
            else:
                right -= 1

# %%
#Q14 Search Insert Position
def searchInsert(self, nums, target):
    left = 0
    right = len(nums) - 1

    while left <= right:
        mid = (left + right) // 2

        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

# %%
# Q15 Group Anagrams
def groupAnagrams(self, strs):
    groups = {}
    for s in strs:
        key = tuple(sorted(s))

        if key not in groups:
            groups[key] = []

        groups[key].append(s)

    return list(groups.values())

# %%
# Q16 Maximum Subarray
def maxSubArray(self, nums):
    curr_sum = max_sum = nums[0]

    for i in range(1, len(nums)):
        curr_sum = max(nums[i], curr_Sum + nums[i])
        max_sum = max(max_sum, curr_sum)

    return max_sum

# %%
# Q17 Merge Sorted Arrays
def merge(self, nums1, m, nums2, n):
    i = m - 1
    j = n - 1
    k = m + n - 1

    while j >= 0:
        if i >= 0 and nums1[i] > nums2[j]:
            nums1[k] = nums1[i]
            i -= 1
        else:
            nums1[k] = nums2[j]
            j -= 1
        k -= 1
    return nums1

# %%
# Q18 Best Time to buy and sell stocks
def maxProfit(self, prices):
    min_price = prices[0]
    max_profit = 0

    for price in prices:
        if price < min_price:
            min_price = price

        current_profit = price - min_price  
        if current_profit > max_profit:
            max_profit = current_profit

    return max_profit

# %%
# Q19 Valid Palindrome
def isPalindrome(self, s):
    l, r = 0, len(s) - 1

    while l < r:
        while l < r and not s[l].isalnum():
            l += 1
        while l < r and not s[r].isalnum():
            r -= 1
        if s[l].lower() != s[r].lower():
            return False

        l += 1
        r -= 1
    return True

# %%
# Q20 Single Number
def singleNumber(self, nums):
    seen = set()

    for num in nums:
        if num in seen:
            seen.remove(num)
        else:
            seen.add(num)

    return seen.pop()

# %%
# Q22 Reverse Words in a string 
def reverseWords(self, s):
    words = s.split()
    left = 0
    right = len(words) - 1

    while left < right:
        words[left], words[right] = words[right], words[left]
        right -= 1
        left += 1

    return " ".join(words)

# %%
# Q23 Two Sum II 
def twoSum(self, numbers, target):
    left, right = 0, len(nums) - 1

    while left < right:
        curr_sum = numbers[left] + numbers[right]

        if curr_sum == target:
            return [left + 1, right + 1]
        elif curr_Sum < target:
            left += 1
        else:
            right -= 1

    return []

# %%
# Q24 Majority Element 
def majorityElement(self, nums):    
    counts = {}
        
    for num in nums:
        counts[num] = counts.get(num, 0) + 1
        if counts[num] > len(nums) // 2:
            return num

# %%
# Q25 Rotate Array
def rotate(self, nums, k):
    k = k % len(nums)
    nums[:] = nums[-k:] + nums[:-k]

    return nums

# %%
# Q26 Happy Number
def isHappy(self, n):
    seen = set()

    while n != 1 and n not in seen:
        seen.add(n)

        total = 0
        while n > 0:
            digit = n % 10
            total += digit * digit
            n //= 10

        n = total

    return n == 1

# %%
# Q27 Minimum size subarray sum 
def minSubArrayLen(self, target, nums):
    left = 0
    seen = set()
    max_length = 0

    for right in range(len(s)):
        while s[right] in seen:
            seen.remove(s[left])
            left += 1
            
        seen.add(s[right])

        max_length = max(max_length, right - left + 1)
        
    return max_length

# %%
# Q28 Contains Duplicate
def containsDuplicate(self, nums):
    seen = set()
    for num in nums:
        if num in seen:
            return True
        else:
            seen.add(nums)
            
    return False

# %%
# Q29 Power of two
def isPowerOfTwo(self, n):
    if n <= 0:
        return False

    while n % 2 == 0:
        n // 2

    return n == 1

# %%
# Q30 Product of array except self
def productExceptSelf(self, nums):
    prefix = [1] * len(nums)
    suffix = [1] * len(nums)

    for i in range(1, len(nums)):
        prefix[i] = prefix[i - 1] * nums[i - 1]

    for i in range(len(nums) - 2, -1, -1):
        suffix[i] = suffix[i + 1] * nums[i + 1]

    answer = []

    for i in range(len(nums)):
        answer.append(prefix[i] * suffix[i])

    return answer

# %%
# Q31 Valid Anagram 
def isAnagram(self, s, t):
    s_map = {}
    t_map = {}

    for char in s:
        if char in s_map:
            s_map[char] += 1
        else:
            s_map[char] = 1
        
    for char in t:
        if char in t_map:
            t_map[char] += 1
        else:
            t_map[char] = 1
        
    return s_map == t_map

# %%
# Q32 Add Digits
def addDigits(self, num):
    while num >= 10:
        total = 0

        while num > 0:
            total += num % 10
            num //= 10

        num = total

    return num

# %%
# Q33 Missing Number
def missingNumber(self, nums):
    nums.sort()

    for i in range(len(nums)):
        if nums[i] != i:
            return i

    return len(nums)

# %%
# Q34 Move Zeros
def moveZeroes(self, nums):
    i = 0

    while i < len(nums):
        if nums[i] == 0:
            nums.pop(i)
            nums.append(0)
        else:
            i += 1

# %%
# Q35 Power of three
def isPowerOfThree(self, n):
    if n <= 0:
        return False

    while n % 3 == 0:
        n //= 3

    return n == 1

# %%
# Q36 Power of 4
def isPowerOfFour(self, n):
    if n <= 0:
        return False

    while n % 4 == 0:
        n //= 4

    return n == 1

# %%
# Q37 Reverse String 
def reverseString(self, s):
    left = 0
    right = len(s) - 1

    while left < right:
        s[left], s[right] = s[right], s[left]
        left += 1
        right -= 1

# %%
# Q38 Top K frequent Elements
def topKFrequent(self, nums, k):
    count = {}

    for num in nums:
        count[num] = count.get(num, 0) + 1

    sorted_nums = sorted(count.items(), key=lambda x: x[1], reverse=True)

    result = []

    for i in range(k):
        result.append(sorted_nums[i][0])

    return result

# %%
# Q39 Ransome Note
def canConstruct(self, ransomNote, magazine):
    for ch in ransomNote:
        if ch not in magazine:
            return False

        magazine = magazine.replace(ch, "", 1)

    return True

# %%
# Q40 First Unique Charecter In a string 
def firstUniqChar(self, s):
    count = {}

    for ch in s:
        count[ch] = count.get(ch, 0) + 1

    for i in range(len(s)):
        if count[s[i]] == 1:
            return i

    return -1

# %%
# Q41 Find All Numbers Disappeared In an array
def findDisappearedNumbers(self, nums):
    seen = set(nums)
    result = []

    for i in range(1, len(nums) + 1):
        if i not in seen:
            result.append(i)

    return result

# %%
# Q42 Subarray Sum equals k
def subarraySum(self, nums, k):
    count = 0

    for i in range(len(nums)):
        total = 0

        for j in range(i, len(nums)):
            total += nums[j]

            if total == k:
                count += 1

    return count

# %%
#Q43 Maximum Average Subarray
def findMaxAverage(self, nums, k):
    current_sum = sum(nums[:k])
    max_sum = current_sum

    for right in range(k, len(nums)):
        current_sum += nums[right]
        current_sum -= nums[right - k]

        max_sum = max(max_sum, current_sum)
        
    return max_sum / float(k)

# %%
# Q44 Binary Search
def search(self, nums, target):
    left = 0
    right = len(nums) - 1

    while left <= right:
        mid = (left + right) // 2

        if nums[mid] == target:
            return mid
            
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
        
    return -1

# %%
# Q46 Squares of a sorted Array
def sortedSquares(self, nums):
    left = 0 
    right = len(nums) - 1

    result = [0] * len(nums)
    index = len(result) - 1

    while left <= right:
        if abs(nums[right]) > abs(nums[left]):
            result[index] = nums[right] ** 2
            right -= 1
        else:
            result[index] = nums[left] ** 2
            left += 1

        index -= 1
        
    return result

# %%
# Q47 Max Consecutive ones III
def longestOnes(self, nums, k):
    left = 0

    for right in range(len(nums)):
        if nums[right] == 0:
            k -= 1

        while k < 0:
            if nums[left] == 0:
                k += 1
            left += 1

    return right - left + 1

# %%
# Q48 How many numbers are smaller than the current number
def smallerNumbersThanCurrent(self, nums):
    result = []

    for i in range(len(nums)):
        count = 0

        for j in range(len(nums)):
            if nums[j] < nums[i]:
                count += 1

        result.append(count)

    return result

# %%
# Q49 Shuffle the array
def shuffle(self, nums, n):
    result = []

    for i in range(n):
        result.append(nums[i])
        result.append(nums[i + n])

    return result

# %%
# Q50 Running sum of 1D array
def runningSum(self, nums):
    for i in range(1, len(nums)):
        nums[i] += nums[i - 1]

    return nums

# %%
# Q51 Merge Strings alternatively 
def mergeAlternately(self, word1, word2):
    result = ""
    i = 0

    while i < len(word1) and i < len(word2):
        result += word1[i]
        result += word2[i]
        i += 1

    result += word1[i:]
    result += word2[i:]

    return result

# %%
# #Q52 Build array from permutation
def buildArray(self, nums):
    result = []

    for i in range(len(nums)):
        result.append(nums[nums[i]])

    return result

# %%
# Q53 Concatenation of array
def getConcatenation(self, nums):
    result = []

    for num in nums:
        result.append(num)

    for num in nums:
        result.append(num)

    return result

# %%
# Q54 Find Closest number to zero
def findClosestNumber(self, nums):    
    closest = nums[0]

    for num in nums:
        if abs(num) < abs(closest):
            closest = num
        elif abs(num) == abs(closest) and num > closest:
            closest = num

    return closest
